# %%
# with function
def main():
  str = input("CamelCase: ")
  snake(str)

def snake(n):
  b = "SnakeCase: "
  for i in n:
    if i ==" ":
      i = "_"
    elif i == i.capitalize():
      i = i.casefold()
    b += i
  final(b)

def final(c):
  print(c)


main()
# Out:
# CamelCase: ALI AKBAR KHAN
# SnakeCase: ali_akbar_khan

# %%
#without functions
j = 0
b = "SnakeCase: "
str = input("CamelCase: ")
for i in str:
  if i ==" ":
    i = "_"
  elif i == i.capitalize() :
    i = i.casefold()

  b += i
print(b)
# Out:
# CamelCase: Prefferd First Name
# SnakeCase: prefferd_first_name
