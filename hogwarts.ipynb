# %%
students = ["Hermoine","Harry","Ron"]
print(students[0])
print(students[1])
print(students[2])
# Out:
# Hermoine
# Harry
# Ron

# %%
students = ["Hermoine","Harry","Ron","Ali"]
i = 0
while i < 4:
  print(students[i])
  i +=1
# Out:
# Hermoine
# Harry
# Ron
# Ali

# %%
students = ["Hermoine","Harry","Ron"]
for _ in students:
  print(students)
# Out:
# ['Hermoine', 'Harry', 'Ron']
# ['Hermoine', 'Harry', 'Ron']
# ['Hermoine', 'Harry', 'Ron']

# %%
students = ["Hermoine","Harry","Ron"]
for _ in range(len(students)):
  print(_+1,students[_])
# Out:
# 1 Hermoine
# 2 Harry
# 3 Ron

# %%
students = ["Harris","Bhuppi","Tayyab","Ali"]
house = ["Raman", "Shivaji", "Ashoka", "Tagor"]

# %%
students = {
    "Hermoine": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slytherin",
}
print(students["Hermoine"])
print(students["Harry"])
print(students["Ron"])
print(students["Draco"])
# Out:
# Gryffindor
# Gryffindor
# Gryffindor
# Slytherin

# %%
students = {
    "Ali": "Tagor",
    "Bhuppi": "Shivaji",
    "Harris": "Raman",
    "Tayyab": "Ashoka",

}
for st in students:
  print(st, students[st], sep=", ")
  # this creates a clean separation of a , between each item printed.
# Out:
# Ali, Tagor
# Bhuppi, Shivaji
# Harris, Raman
# Tayyab, Ashoka

# %%
students = [
    {"Name":"Ali Akbar Khan", "House":"Tagor", "Age": "18", "Gender":"Male"},
    {"Name":"Hasan Akbar Khan", "House":"Ashoka", "Age": "14", "Gender":"Male"},
    {"Name":"Akbar Khan", "House":None, "Age": "45", "Gender":"Male"},
    {"Name":"Rizwana Khan", "House":"Shivagi", "Age": "43", "Gender":"Female"}
]
for _ in students:
  print(_["Name"],_["House"],_["Age"],_["Gender"], sep =",  ")
# Out:
# Ali Akbar Khan,  Tagor,  18,  Male
# Hasan Akbar Khan,  Ashoka,  14,  Male
# Akbar Khan,  None,  45,  Male
# Rizwana Khan,  Shivagi,  43,  Female

# %%
print("#")
print("#")
print("#")
# Out:
# #
# #
# #

# %%
for _ in range(3):
  print("#")
# Out:
# #
# #
# #

# %%
def main():
  n = int(input("enter number: "))
  cavalue(n)

def cavalue(hight):
  for _ in range(hight):
    print("#")

main()
# Out:
# enter number: 4
# #
# #
# #
# #

# %%
def main():
  n = int(input("enter width: "))
  wi(n)
def wi(width):
    print("$"*width)
main()
# Out:
# enter width: 5
# $$$$$

# %%
def main():
  n = int(input("enter width: "))
  wi(n)
def wi(width):
  for _ in range(width):
    print("$"*width)
main()
# Out:
# enter width: 3
# $$$
# $$$
# $$$
