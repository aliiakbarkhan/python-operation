# %%
def main():
  i = 50
  fun(i)

def fun(n):
  while n>=0:
    print("Amount Due:",n)
    ins = int(input("Insert Amount:"))
    n = n - ins
    if(n<0):
      print("Change Owed:",abs(n))

main()
# Out:
# Amount Due: 50
# Insert Amount:25
# Amount Due: 25
# Insert Amount:10
# Amount Due: 15
# Insert Amount:25
# Change Owed: 10

# %%
# without function
ins = 0
i = 50
while(i>=0):
  print("Amount Due:",i)
  ins = int(input("Insert Amount:"))
  i = i - ins
  if(i < 0):
    print("Change Owed:",abs(i))
# Out:
# Amount Due: 50
# Insert Amount:30
# Amount Due: 20
# Insert Amount:30
# Change Owed: 10
