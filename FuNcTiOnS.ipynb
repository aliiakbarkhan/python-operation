# %%
# Out:
# enter number:4
# 4 is a prime

# %%
#  Write a  Python function to check whether a number falls within a given rang.
def range(a,b,n):
  if(n>a and n<b):
    print(n,"is in range of",a,"to",b)
  else:
    print(n,"is not in range of",a,"to",b)

a = int(input("enter starting range:"))
b = int(input("enter ending range:"))
n = int(input("enter number range:"))
range(a,b,n)

# %%
# Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number as an argument.
def factorial(n):
  if(n==0):
    return n;
  else:
    for i in range(1,n):
      n = n*i
  print(n)

a = int(input("enter number:"))
factorial(a)

# %%
#  Write a  Python function to find the maximum of three numbers.
def max(a,b,c):
  if(a>b and b>c):
    print(a)
  elif(b>a and b>c):
    print(b)
  else:
    print(c)
a = int(input("enter number a:"))
b = int(input("enter number b:"))
c = int(input("enter number c:"))
max(a,b,c)

# %%
i = 0
l = [23,45,32,25,46,33,71,90]
while(i<=7):
  if(l[i]%2!=0):
    print(l[i])
  i = i+1

# %%
i = 0
j = 50
while(i<=50):
  i = i+1
  j = j-1
  print(i,"----",j)

# %%
from re import I
i = 1
sum = 0
nev = 0
target = int(input("enter Nth term: "))
while(i<=target):
  if(i%2==0):
    sum = sum + i*i
  elif(i%2!=0):
    nev = nev + i*i
  i = i+1
print(sum-nev)
