# %%
def main():
  n = input("Fruit Name: ")
  calori(n)

def calori(n):
  fruits = {
    "apple":"130",
    "avacado":"50",
    "banana":"110",
    "cantaloupe":"50",
    "grapefruit":"60",
    "grapes":"90",
    "honeydew melon":"50",
    "kiwifruit":"90",
    "lemon":"15",
    "lime":"20",
    "nactarine":"60",
    "orange":"80",
    "peach":"60",
    "pear":"100",
    "pineapple":"50",
    "plums":"50",
    "sweet cherries":"100",
    "tangerine":"50",
    "watermelon":"80",}
  for _ in fruits:
    if(n == _):
      print("Calories: ",fruits[_])



main()
# Out:
# Fruit Name: lime
# Calories:  20

# %%
fruits = {
    "apple":"130",
    "avacado":"50",
    "banana":"110",
    "cantaloupe":"50",
    "grapefruit":"60",
    "grapes":"90",
    "honeydew melon":"50",
    "kiwifruit":"90",
    "lemon":"15",
    "lime":"20",
    "nactarine":"60",
    "orange":"80",
    "peach":"60",
    "pear":"100",
    "pineapple":"50",
    "plums":"50",
    "sweet cherries":"100",
    "tangerine":"50",
    "watermelon":"80",}
for _ in fruits:
  print(fruits[_])
# Out:
# 130
# 50
# 110
# 50
# 60
# 90
# 50
# 90
# 15
# 20
# 60
# 80
# 60
# 100
# 50
# 50
# 100
# 50
# 80
