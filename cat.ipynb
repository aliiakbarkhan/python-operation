# %%
i = 4
while i != 0:
  print("meow")
  i = i-1
# Out:
# meow
# meow
# meow
# meow

# %%
i = 1
while i <= 4:
  print("meow")
  i = i+1
# Out:
# meow
# meow
# meow
# meow

# %%
# i += 1 is the same as saying i = i + 1
i = 0
while i < 3:
  print("meow")
  i+=1
# Out:
# meow
# meow
# meow

# %%
for i in [0,1,2]:
  print(i,"meow")
# Out:
# 0 meow
# 1 meow
# 2 meow

# %%
for i in range(5):
  print("meow")
# Out:
# meow
# meow
# meow
# meow
# meow

# %%
# changing the i to _ has zero impact on the functioning of our program
for _ in range(4):
  print("meow")
# Out:
# meow
# meow
# meow
# meow

# %%
print("meow\n"*3)
# Out:
# meow
# meow
# meow

# %%
while True:
  n = int(input("enter number: "))
  if n < 0:
    # we’ve introduced two new keywords in Python, continue and break
    continue
  else:
    break
print("loop ended")
# Out:
# enter number: -7
# enter number: -9
# enter number: -8
# enter number: 6
# loop ended

# %%
while True:
  n = int(input("enter number"))
  if n > 0:
    break
for _ in range(n):
  print("meow")
# Out:
# enter number6
# meow
# meow
# meow
# meow
# meow
# meow

# %%
def main():
  ffor(wlooping())

def wlooping():
  while True:
    n = int(input("enter number: "))
    if n > 0:
      return n

def ffor(n):
  for _ in range(n):
    print("meow")
main()
print("ended")
# Out:
# enter number: 5
# meow
# meow
# meow
# meow
# meow
# ended
