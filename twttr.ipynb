# %%
sent = "Output: "
word = input("Input: ")
for i in word:
  if i != "A"and i !="E"and i!="I"and i!="O"and i!="U" and i!="a" and i!="e" and i!="i" and i!="o" and i!="u":

    sent+=i

  else:
    continue
print(sent)
# Out:
# Input: 56
# Output: 56
