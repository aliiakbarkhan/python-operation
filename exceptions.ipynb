# %%
# syntex error
print("hello, world)
# Out:
#   File "<ipython-input-2-40c7a828f72a>", line 1
#     print("hello, world)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# runtime error
try:
  x = int(input("enter number: "))
  print(f"x is{x}")
except ValueError:
  print("x is not a integer")
# Out:
# enter number: 1
# x is1

# %%
try:
    x = int(input("What's x?"))
except ValueError:
    print("x is not an integer")
else:
  print(f"x is {x}")
# Out:
# What's x?23
# x is 23

# %%
# while True will loop forever
while True:
  try:
    x = int(input("Enter Number:"))
  except ValueError:
    print("Input Is Not Int")
  else:
    break

print(f"x is {x}")
# Out:
# Enter Number:ali
# Input Is Not Int
# Enter Number:2345
# x is 2345

# %%
def result():
  n = trying()
  print(f"x is {n}")


def trying():
  while True:
    try:
      x = int(input("Enter Value: "))
    except ValueError:
      print("Input is not integer")
    else:
      return x



result()
# Out:
# Enter Value: 4
# x is 4

# %%
def main():
    x = get_int()
    print(f"x is {x}")


def get_int():
    while True:
        try:
            x = int(input("What's x?"))
        except ValueError:
            print("x is not an integer")
        else:
            break
    return x


main()
# Out:
# What's x?ali
# x is not an integer
# What's x?4
# x is 4

# %%
def main():
    x = get_int()
    print(f"x is {x}")


def get_int():
    while True:
        try:
            x = int(input("What's x?"))
        except ValueError:
            pass
            # our code does not warn our user, but simply re-asks them our prompting question
        else:
            break
    return x


main()
# Out:
# What's x?ali
# What's x?4
# x is 4
