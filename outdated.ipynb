# %%
list = [
    "January",
    "February",
    "March",
    "April",
    "May",
    "June",
    "July",
    "August",
    "September",
    "October",
    "November",
    "December"
]
def func():
  try:
    m,d,y = input("Date: ").split("/")
    check(m,d,y)

  except ValueError:
    func()

def check(m,d,y):
  for _ in list:
    if m in list:
      print(f"{y}-{m}-{d}")
      break
  else:
      func()

func()
# code still lack some functionlities
# Out:
# Date: 9/30/2023
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7b7051af65f8> in <cell line: 32>()
#      30       func()
#      31
# ---> 32 func()
#
# <ipython-input-31-7b7051af65f8> in func()
#      16   try:
#      17     m,d,y = input("Date: ").split("/")
# ---> 18     check(m,d,y)
#      19
#      20   except ValueError:
#
# <ipython-input-31-7b7051af65f8> in check(m, d, y)
#      23 def check(m,d,y):
#      24   for _ in list:
# ---> 25     m = list[m]
#      26
#      27     print(f"{y}-{m}-{d}")
#
# TypeError: list indices must be integers or slices, not str

# %%
# rough
list = [
    "January",
    "February",
    "March",
    "April",
    "May",
    "June",
    "July",
    "August",
    "September",
    "October",
    "November",
    "December"
]
m = 2
print(list[m])
# Out:
# March
