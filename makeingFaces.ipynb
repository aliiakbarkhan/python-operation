# %%
def main():
  convert = input("$: ")
  change(convert)

def change(convert):
  if ":(" in convert:
    print(convert.replace(":(", "😐"))
  elif ":)" in convert:
    print(convert.replace(":)", "🙂"))
  else:
    print(convert)
main()
# Out:
# $: ali:(
# ali😐

# %%
while True:
  inp = input(":")
  print(inp.casefold())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-766a9839c9d9> in <cell line: 1>()
#       1 while True:
# ----> 2   inp = input(":")
#       3   print(inp.casefold())
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
while True:
  inp = input(":")
  print(inp.replace(" ","..."))
# Out:
# :Ali Akbar
# Ali...Akbar
# :Ali Akbar Khan
# Ali...Akbar...Khan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a37ad71f2918> in <cell line: 1>()
#       1 while True:
# ----> 2   inp = input(":")
#       3   print(inp.replace(" ","..."))
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
def main():
  meal = int(input("How much was the meal? "))
  tipp = int(input("What percentage would you like to tip? "))
  final(meal, tipp)







def final(m, t):
  print("Leave: ",m*(t/100))
main()
# Out:
# How much was the meal? $50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-4d98986e5680> in <cell line: 15>()
#      13 def final(m, t):
#      14   print("Leave: ",m*(t/100))
# ---> 15 main()
#
# <ipython-input-23-4d98986e5680> in main()
#       1 def main():
# ----> 2   meal = input("How much was the meal? $")
#       3
#       4   tipp = int(input("What percentage would you like to tip? "))
#       5   final(meal, tipp)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
